# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('zomato.csv')
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.describe(include='all')
# Out:
#                                                       url        address  \
# count                                               51717          51717
# unique                                              51717          11495
# top     https://www.zomato.com/bangalore/jalsa-banasha...  Delivery Only
# freq                                                    1            128
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#                    name online_order book_table   rate         votes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.drop(['url','address','phone','menu_item'], axis=1, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 72

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
from fuzzywuzzy import fuzz

# %%
import pandas as pd

# Assuming 'name' is the actual column name in your DataFrame
result_df = pd.DataFrame({
    'name': df['name'],
    'similarity_percentage': df['name'].apply(calculate_similarity_percentage)
})

# Group by 'similarity_percentage' and get unique values for 'name'
unique_values_by_percentage = result_df.groupby('similarity_percentage')['name'].unique()

# Sort percentages in descending order
sorted_percentages = sorted(unique_values_by_percentage.keys(), key=lambda x: float(x.rstrip('%')), reverse=True)

# Display the result
for percentage in sorted_percentages:
    values = unique_values_by_percentage[percentage]
    print(f"Percentage: {percentage}")
    print("Unique Values:")
    for value in values:
        print(f"  - {value}")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-1d0296aaa04c> in <module>
#       4 result_df = pd.DataFrame({
#       5     'name': df['name'],
# ----> 6     'similarity_percentage': df['name'].apply(calculate_similarity_percentage)
#       7 })
#       8
#
# NameError: name 'calculate_similarity_percentage' is not defined

# %%
df['name'].value_counts()
# Out:
# Cafe Coffee Day                                            96
# Onesta                                                     85
# Just Bake                                                  73
# Empire Restaurant                                          71
# Five Star Chicken                                          70
#                                                            ..
# Hyderabadi Biryaani Hub                                     1
# Lassi Mania                                                 1
# Coastal Biryani Paradise                                    1
# Momo Shop                                                   1
# Plunge - Sheraton Grand Bengaluru Whitefield Hotel &...     1
# Name: name, Length: 8792, dtype: int64

# %%
df[df['name'].str.contains('yummy',case=False)]
# Out:
#                             name online_order book_table    rate  votes  \
# 434                  Yummy Momos          Yes         No   3.2/5      4
# 1135                 Yummy Momos          Yes         No   3.6/5     44
# 1453                 Yummy Momos          Yes         No     NEW      0
# 1530             The Yummy Tummy           No         No   3.5/5     13
# 2133             The Yummy Tummy           No         No   3.5/5     13
# ...                          ...          ...        ...     ...    ...
# 49983                Yummy Tummy          Yes         No  2.9 /5    114
# 50629         Yummy Dum Biriyani           No         No     NaN      0
# 50681           Yummy Beeriyaniz           No         No     NaN      0
# 51412  Hyderabadi Biryummy House           No         No     NaN      0
# 51453         Yummy Dum Biriyani           No         No     NaN      0
#
#                  location           rest_type      dish_liked  \
# ...

# %%
df['online_order'].value_counts()
# Out:
# Yes    30386
# No     21259
# Name: online_order, dtype: int64

# %%
df['book_table'].value_counts()
# Out:
# No     45208
# Yes     6437
# Name: book_table, dtype: int64

# %%
sorted(df['rate'].astype(str).unique())
# Out:
# ['-',
#  '1.8 /5',
#  '1.8/5',
#  '2.0 /5',
#  '2.0/5',
#  '2.1 /5',
#  '2.1/5',
#  '2.2 /5',
#  '2.2/5',
#  '2.3 /5',
#  '2.3/5',
#  '2.4 /5',
#  '2.4/5',
#  '2.5 /5',
#  '2.5/5',
#  '2.6 /5',
#  '2.6/5',
#  '2.7 /5',
#  '2.7/5',
#  '2.8 /5',
#  '2.8/5',
#  '2.9 /5',
#  '2.9/5',
#  '3.0 /5',
#  '3.0/5',
#  '3.1 /5',
#  '3.1/5',
#  '3.2 /5',
#  '3.2/5',
#  '3.3 /5',
#  '3.3/5',
#  '3.4 /5',
#  '3.4/5',
#  '3.5 /5',
#  '3.5/5',
#  '3.6 /5',
#  '3.6/5',
#  '3.7 /5',
#  '3.7/5',
#  '3.8 /5',
#  '3.8/5',
#  '3.9 /5',
#  '3.9/5',
#  '4.0 /5',
#  '4.0/5',
#  '4.1 /5',
#  '4.1/5',
#  '4.2 /5',
#  '4.2/5',
#  '4.3 /5',
#  '4.3/5',
#  '4.4 /5',
#  '4.4/5',
#  '4.5 /5',
#  '4.5/5',
#  '4.6 /5',
#  '4.6/5',
#  '4.7 /5',
#  '4.7/5',
#  '4.8 /5',
#  '4.8/5',
#  '4.9 /5',
#  '4.9/5',
#  'NEW',
#  'nan']

# %%
def fix_rate(r):
    try:
        return float(r[0:3])
    except:
        return np.nan

# %%
df['rate'] = df['rate'].apply(fix_rate)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51645 entries, 0 to 51644
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51645 non-null  object
#  1   online_order                 51645 non-null  object
#  2   book_table                   51645 non-null  object
#  3   rate                         41622 non-null  float64
#  4   votes                        51645 non-null  int64
#  5   location                     51624 non-null  object
#  6   rest_type                    51418 non-null  object
#  7   dish_liked                   23626 non-null  object
#  8   cuisines                     51600 non-null  object
#  9   approx_cost(for two people)  51300 non-null  object
#  10  reviews_list                 51645 non-null  object
#  11  listed_in(type)              51645 non-null  object
#  12  listed_in(city)              51645 non-null  object
# ...

# %%
df['approx_cost(for two people)'].astype(str).unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', 'nan', '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %%
df["approx_cost(for two people)"] = df["approx_cost(for two people)"].astype(str).apply(lambda r : float(r.replace("," , "")))

# %%
df['listed_in(type)'].unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks & nightlife', 'Pubs and bars'], dtype=object)

# %%
df['listed_in(city)'].unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block',
#        'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
#        'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
#        'Old Airport Road', 'Rajajinagar', 'Residency Road',
#        'Sarjapur Road', 'Whitefield'], dtype=object)

# %%
grouped_sums = []
for name in df['name'].unique():
    # Filter rows where the 'name' column is equal to the current name
    filtered_df = df[df['name'] == name]
    
    # Calculate the sum for the current group
    group_sum = filtered_df['name'].sum()
    
    # Append the result to the list
    grouped_sums.append({'name': name, 'sum': group_sum})
    
grouped_sums
# Out:
# [{'name': 'Jalsa',
#   'sum': 'JalsaJalsaJalsaJalsaJalsaJalsaJalsaJalsaJalsaJalsaJalsa'},
#  {'name': 'Spice Elephant',
#   'sum': 'Spice ElephantSpice ElephantSpice ElephantSpice Elephant'},
#  {'name': 'San Churro Cafe',
#   'sum': 'San Churro CafeSan Churro CafeSan Churro CafeSan Churro CafeSan Churro CafeSan Churro CafeSan Churro CafeSan Churro CafeSan Churro CafeSan Churro CafeSan Churro Cafe'},
#  {'name': 'Addhuri Udupi Bhojana',
#   'sum': 'Addhuri Udupi BhojanaAddhuri Udupi Bhojana'},
#  {'name': 'Grand Village',
#   'sum': 'Grand VillageGrand VillageGrand VillageGrand Village'},
#  {'name': 'Timepass Dinner',
#   'sum': 'Timepass DinnerTimepass DinnerTimepass DinnerTimepass DinnerTimepass DinnerTimepass DinnerTimepass Dinner'},
#  {'name': 'Rosewood International Hotel - Bar & Restaurant',
#   'sum': 'Rosewood International Hotel - Bar & RestaurantRosewood International Hotel - Bar & RestaurantRosewood International Hotel - Bar & Restaurant'},
#  {'name': 'Onesta',
# ...

# %%
# Group by 'name' and calculate the count for each group
grouped_counts = df['name'].value_counts().reset_index()
grouped_counts.columns = ['name', 'repeat_count']

# Merge the original DataFrame with the grouped counts
result_df = pd.merge(df, grouped_counts, on='name')

# Display the result
result_df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                                  Jalsa          Yes
# 2                                                  Jalsa          Yes
# 3                                                  Jalsa          Yes
# 4                                                  Jalsa          Yes
# ...                                                  ...          ...
# 51640                       The Nest - The Den Bengaluru           No
# 51641                       The Nest - The Den Bengaluru           No
# 51642                                      Nawabs Empire           No
# 51643                                   SeeYa Restaurant           No
# 51644  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       book_table  rate  votes                    location           rest_type  \
# ...

# %%
result_df.duplicated().sum()
# Out:
# 0

# %%
df.groupby('name').sum()
# Out:
#                                               rate  votes  \
# name
# #FeelTheROLL                                   6.8     14
# #L-81 Cafe                                    35.1    432
# #Vibes Restro                                  0.0      0
# #refuel                                       11.1    111
# 'Brahmins' Thatte Idli                         0.0      0
# ...                                            ...    ...
# late100                                        0.0      0
# nu.tree                                       30.2   1443
# re:cess - Hilton Bangalore Embassy GolfLinks  12.3    438
# repEAT Hub                                     0.0      0
# sCoolMeal                                      0.0      0
#
#                                               approx_cost(for two people)
# name
# #FeelTheROLL                                                        400.0
# #L-81 Cafe                                                         3600.0
# ...

# %%
df.shape
# Out:
# (51645, 13)

# %%
result_df.shape
# Out:
# (51645, 14)

# %%
merged_df = pd.merge(result_df, df, how='left', on='name', suffixes=('_result', '_df'))
df['Name_repeated'] = result_df['repeat_count'].combine_first(merged_df['repeat_count'])
print(df)
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51640  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51641                           Vinod Bar And Restaurant           No
# 51642  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51643  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51644                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51640  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51641                           Vinod Bar And Restaurant           No
# 51642  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51643  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51644                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### What are the most 20 popular types in each feature

# %%
plt.figure(figsize=[25,18])

features=['location','rest_type','cuisines','listed_in(type)','listed_in(city)','name','dish_liked','online_order','book_table']
n=1

for f in features:
    plt.subplot(3,3,n)
    order=df[f].value_counts().head(20).index
    sns.countplot(y=df[f],order=order);
    sns.despine()
    plt.title("Countplot of {}".format(f))
    n=n+1
plt.tight_layout()

# %%
def Encode(df):
    for column in df.columns[~df.columns.isin(['rate', 'cost', 'votes'])]:
        df[column] = df[column].factorize()[0]
    return df

zomato_en = Encode(df.copy())

# %%
#Get Correlation between different variables
corr = zomato_en.corr(method='kendall')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
zomato_en.columns
# Out:
# Index(['online_order', 'book_table', 'rate', 'location', 'rest_type',
#        'cuisines', 'approx_cost(for two people)', 'listed_in(type)',
#        'listed_in(city)', 'Name_repeated'],
#       dtype='object')

# %% [markdown]
# ### Classifing the rate based on it's Cuisines

# %%
def Create_Target(r):
    if r >= 3.75:
        return 1
    else:
        return 0

# %%
df["rate"] = df["rate"].apply(Create_Target)

# %%
cuisines_10_index = df['cuisines'].value_counts().head(10).index
cuisines_top_10 = df[df['cuisines'].isin(cuisines_10_index)]

# %%
cuisines = pd.crosstab(cuisines_top_10['cuisines'],df['rate'])
cuisines
# Out:
# rate                                    0    1
# cuisines
# Bakery                                574   77
# Bakery, Desserts                      621  290
# Biryani                               777  141
# Cafe                                  457  299
# Desserts                              430  336
# Fast Food                             684  119
# North Indian                         2068  845
# North Indian, Chinese                1991  394
# South Indian                         1420  408
# South Indian, North Indian, Chinese   536  190

# %%
cuisines.div(cuisines.sum(1).astype(float),axis=0)
# Out:
# rate                                        0         1
# cuisines
# Bakery                               0.881720  0.118280
# Bakery, Desserts                     0.681668  0.318332
# Biryani                              0.846405  0.153595
# Cafe                                 0.604497  0.395503
# Desserts                             0.561358  0.438642
# Fast Food                            0.851806  0.148194
# North Indian                         0.709921  0.290079
# North Indian, Chinese                0.834801  0.165199
# South Indian                         0.776805  0.223195
# South Indian, North Indian, Chinese  0.738292  0.261708

# %%
cuisines.div(cuisines.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True)

# %% [markdown]
# ### Classifing the rate based on it's Resturant Type

# %%
rest_10_index = df['rest_type'].value_counts().head(10).index
rest_top_10 = df[df['rest_type'].isin(rest_10_index)]

# %%
rest = pd.crosstab(rest_top_10['rest_type'],df['rate'])
rest.div(rest.sum(1).astype(float),axis=0)
# Out:
# rate                       0         1
# rest_type
# Bakery              0.798422  0.201578
# Bar                 0.470588  0.529412
# Beverage Shop       0.749712  0.250288
# Cafe                0.397106  0.602894
# Casual Dining       0.465344  0.534656
# Casual Dining, Bar  0.212305  0.787695
# Delivery            0.774962  0.225038
# Dessert Parlor      0.451171  0.548829
# Quick Bites         0.774671  0.225329
# Takeaway, Delivery  0.846343  0.153657

# %%
rest.div(rest.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True)

# %%
px.histogram(df,y = "votes", x = 'listed_in(city)')
# Out:
# <div>                            <div id="2be0aa23-b87b-4bfd-ac84-f4a60a1e7d30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2be0aa23-b87b-4bfd-ac84-f4a60a1e7d30")) {                    Plotly.newPlot(                        "2be0aa23-b87b-4bfd-ac84-f4a60a1e7d30",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"listed_in(city)=%{x}<br>sum of votes=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","Banashankari","B
# ...

# %% [markdown]
# ## Missing Values

# %%
df.isna().mean()
# Out:
# name                           0.000000
# online_order                   0.000000
# book_table                     0.000000
# rate                           0.194075
# votes                          0.000000
# location                       0.000407
# rest_type                      0.004395
# dish_liked                     0.542531
# cuisines                       0.000871
# approx_cost(for two people)    0.006680
# reviews_list                   0.000000
# listed_in(type)                0.000000
# listed_in(city)                0.000000
# Name_repeated                  0.000000
# dtype: float64

# %%
df.loc[df['approx_cost(for two people)'].isna(), 'rate'].isna().sum()
# Out:
# 99

# %%
df.loc[df['approx_cost(for two people)'].isna(), 'rest_type'].isna().sum()
# Out:
# 23

# %%
df.loc[df['rest_type'].isna(), 'rate'].isna().sum()
# Out:
# 78

# %%
df = df.dropna(subset=['rate','rest_type','approx_cost(for two people)','dish_liked'])

# %%
df.isna().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# listed_in(type)                0
# listed_in(city)                0
# Name_repeated                  0
# dtype: int64

# %%
df.drop(['name','dish_liked','reviews_list','votes'], axis=1, inplace=True)
# Out:
# C:\Users\Seif\anaconda3\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
x = df.drop("rate" , axis = 1 )
y = df["rate"]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder , RobustScaler , StandardScaler, LabelEncoder, FunctionTransformer
from category_encoders.binary import BinaryEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate

# %%
Encoder = ColumnTransformer(transformers=[("BE",BinaryEncoder() , [ "online_order","book_table","listed_in(type)","location","listed_in(city)",'rest_type','cuisines',]) ], remainder="passthrough")

# %%
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
steps = []
steps.append(("Encoder" , Encoder))
steps.append(("Scaler" , RobustScaler()))
steps.append(("Model" , LogisticRegression()) )
pipeline = Pipeline(steps = steps)

# %%
df
# Out:
#       online_order book_table  rate                    location  \
# 0              Yes        Yes     1                Banashankari
# 1              Yes         No     1                Banashankari
# 2              Yes         No     1                Banashankari
# 3               No         No     0                Banashankari
# 4               No         No     1                Basavanagudi
# ...            ...        ...   ...                         ...
# 51633          Yes        Yes     1                  Whitefield
# 51635           No         No     1                  Whitefield
# 51636           No         No     0                  Whitefield
# 51639           No         No     0                  Whitefield
# 51643           No        Yes     1  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# ...

# %%
result = cross_validate(pipeline ,x , y, cv = 5 , scoring = "accuracy" , return_train_score=True, error_score='raise')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-1dbbf12b2015> in <module>
# ----> 1 result = cross_validate(pipeline ,x , y, cv = 5 , scoring = "accuracy" , return_train_score=True, error_score='raise')
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     281             error_score=error_score,
#     282         )
# --> 283         for train, test in cv.split(X, y, groups)
#     284     )
#     285
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
# ...

# %%
models = []
models.append(("RF" , RandomForestClassifier(random_state = 0))) #n_estimators = 10, criterion = 'entropy',
models.append(("LR" , LogisticRegression(random_state = 0)))
models.append(("KNN" , KNeighborsClassifier())) # n_neighbors = 5, metric = 'minkowski', p = 2
models.append(("SVC" , SVC( random_state = 0))) # kernel = 'linear'
models.append(("NB" , GaussianNB()))
models.append(('TRC' , DecisionTreeClassifier(random_state = 0))) # criterion = 'entropy'
models.append(("XGB" , XGBClassifier()))

# %% [markdown]
# # First Test for the Model

# %%
# Ftirst test to the model
for model in models:
    steps = []
    steps.append(("Encoder", Encoder))
    steps.append(("Scaler", RobustScaler()))
    steps.append(model)
    pipeline = Pipeline(steps=steps)
    result = cross_validate(pipeline, x, y, cv=5, scoring=['accuracy'], return_train_score=True)
    
    for metric in ['accuracy']:
        train_key = f'train_{metric}'
        test_key = f'test_{metric}'
        
        print(f"{model[0]} AVG Train {metric} is {result[train_key].mean()}")
        print(f"{model[0]} AVG Test {metric} is {result[test_key].mean()}")
    print("*" * 50)
# Out:
# RF AVG Train accuracy is 0.9927625099920633
# RF AVG Test accuracy is 0.761390822861663
# **************************************************
# LR AVG Train accuracy is 0.7656042328593784
# LR AVG Test accuracy is 0.7439250434247624
# **************************************************
# KNN AVG Train accuracy is 0.8411623246884672
# KNN AVG Test accuracy is 0.7078797475234586
# **************************************************
# SVC AVG Train accuracy is 0.7587645720679121
# SVC AVG Test accuracy is 0.7587645764958124
# **************************************************
# NB AVG Train accuracy is 0.6067341786281863
# NB AVG Test accuracy is 0.6048535353885793
# **************************************************
# TRC AVG Train accuracy is 0.9998279344402109
# TRC AVG Test accuracy is 0.8464337202820816
# **************************************************
# XGB AVG Train accuracy is 0.9431217639765268
# XGB AVG Test accuracy is 0.8241918137095039
# ...

# %% [markdown]
# # Testinig after adding rest_type to the encoder

# %%
# After encoding rest_type [ "online_order","book_table","listed_in(type)","location","listed_in(city)",'rest_type','cuisines',]
# to provide more data for the model to train on
for model in models:
    steps = []
    steps.append(("Encoder", Encoder))
    steps.append(("Scaler", RobustScaler()))
    steps.append(model)
    pipeline = Pipeline(steps=steps)
    result = cross_validate(pipeline, x, y, cv=5, scoring=['accuracy'], return_train_score=True)
    
    for metric in ['accuracy']:
        train_key = f'train_{metric}'
        test_key = f'test_{metric}'
        
        print(f"{model[0]} AVG Train {metric} is {result[train_key].mean()}")
        print(f"{model[0]} AVG Test {metric} is {result[test_key].mean()}")
    print("*" * 50)
# Out:
# RF AVG Train accuracy is 0.9953327378096308
# RF AVG Test accuracy is 0.8204939251590699
# **************************************************
# LR AVG Train accuracy is 0.7727018806760653
# LR AVG Test accuracy is 0.7509361106678046
# **************************************************
# KNN AVG Train accuracy is 0.8612294917775418
# KNN AVG Test accuracy is 0.7455622090078338
# **************************************************
# SVC AVG Train accuracy is 0.7587645720679121
# SVC AVG Test accuracy is 0.7587645764958124
# **************************************************
# NB AVG Train accuracy is 0.6152622681794632
# NB AVG Test accuracy is 0.6099290354961294
# **************************************************
# TRC AVG Train accuracy is 0.9999139675092339
# TRC AVG Test accuracy is 0.8682425125532834
# **************************************************
# XGB AVG Train accuracy is 0.9542737337599645
# XGB AVG Test accuracy is 0.842560559907669
# ...

# %% [markdown]
# # After adding all availaible features to the model inorder to provide him with all data needed to be trained on

# %%
# with encoding all features [ "online_order","book_table","listed_in(type)","location","listed_in(city)",'rest_type','cuisines',]
# to provide more data for the model to train on
for model in models:
    steps = []
    steps.append(("Encoder", Encoder))
    steps.append(("Scaler", RobustScaler()))
    steps.append(model)
    pipeline = Pipeline(steps=steps)
    result = cross_validate(pipeline, x, y, cv=5, scoring=['accuracy'], return_train_score=True)
    
    for metric in ['accuracy']:
        train_key = f'train_{metric}'
        test_key = f'test_{metric}'
        
        print(f"{model[0]} AVG Train {metric} is {result[train_key].mean()}")
        print(f"{model[0]} AVG Test {metric} is {result[test_key].mean()}")
    print("*" * 50)
# Out:
# RF AVG Train accuracy is 0.9994730494761329
# RF AVG Test accuracy is 0.8848032898738774
# **************************************************
# LR AVG Train accuracy is 0.7658300173333099
# LR AVG Test accuracy is 0.7444412649731588
# **************************************************
# KNN AVG Train accuracy is 0.9256787309744141
# KNN AVG Test accuracy is 0.832625945688401
# **************************************************
# SVC AVG Train accuracy is 0.8160086718419161
# SVC AVG Test accuracy is 0.7640551488700311
# **************************************************
# NB AVG Train accuracy is 0.604819943998937
# NB AVG Test accuracy is 0.6002502839088993
# **************************************************
# TRC AVG Train accuracy is 0.9994730494761329
# TRC AVG Test accuracy is 0.8552550970609936
# **************************************************
# XGB AVG Train accuracy is 0.9530155299057348
# XGB AVG Test accuracy is 0.8416568437656844
# ...

# %% [markdown]
# # Deploying Model on the cloud

# %%
# %%writefile app.py
%%writefile app.py
import streamlit as st
import pandas as pd
import joblib
import sklearn
import category_encoders

Model = joblib.load("Model.pkl")
Inputs = joblib.load("Inputs.pkl")

def Make_Prdiction(online_order,book_table,location,approx_cost,listed_in,listed_in_city,rest_type_counts,cuisines_counts):
    Pr_df = pd.DataFrame(columns=Inputs)
    Pr_df.at[0,"online_order"] = online_order
    Pr_df.at[0,"book_table"] = book_table
    Pr_df.at[0,"location"] = location
    Pr_df.at[0,"rest_type_counts"] = rest_type_counts
    Pr_df.at[0,"approx_cost(for two people)"] = approx_cost
    Pr_df.at[0,"cuisines_counts"] = cuisines_counts
    Pr_df.at[0,"listed_in(type)"] = listed_in
    Pr_df.at[0,"listed_in(city)"] = listed_in_city
    result = Model.predict(Pr_df)
    return result[0]
    
def main():
    st.title("Zomato Resturants")
    online_order= st.selectbox("online_order",['Yes', 'No']) 
    book_table = st.selectbox("book_table" ,['Yes', 'No'] )
    location = st.selectbox("location" ,['Banashankari', 'Basavanagudi', 'other', 'Jayanagar', 'JP Nagar',
       'Bannerghatta Road', 'BTM', 'Electronic City', 'Shanti Nagar',
       'Koramangala 5th Block', 'Richmond Road', 'HSR',
       'Koramangala 7th Block', 'Bellandur', 'Sarjapur Road',
       'Marathahalli', 'Whitefield', 'Old Airport Road', 'Indiranagar',
       'Koramangala 1st Block', 'Frazer Town', 'MG Road', 'Brigade Road',
       'Lavelle Road', 'Church Street', 'Ulsoor', 'Residency Road',
       'Shivajinagar', 'St. Marks Road', 'Cunningham Road',
       'Commercial Street', 'Vasanth Nagar', 'Domlur',
       'Koramangala 8th Block', 'Ejipura', 'Jeevan Bhima Nagar',
       'Kammanahalli', 'Koramangala 6th Block', 'Brookefield',
       'Koramangala 4th Block', 'Banaswadi', 'Kalyan Nagar',
       'Malleshwaram', 'Rajajinagar', 'New BEL Road'] )
    rest_type_counts = st.selectbox("rest_type_counts" ,[1, 2] )
    approx_cost = st.slider("approx_cost" ,  min_value=40, max_value=6000, value=0, step=1)
    cuisines_counts = st.selectbox("cuisines_counts" ,[3, 2, 1, 4, 5, 8, 7, 6] )
    listed_in = st.selectbox("listed_in_types" ,['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out','Drinks & nightlife', 'Pubs and bars'] )
    listed_in_city = st.selectbox("listed_in_city" ,['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
       'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
       'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
       'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
       'Koramangala 4th Block', 'Koramangala 5th Block',
       'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
       'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
       'Old Airport Road', 'Rajajinagar', 'Residency Road',
       'Sarjapur Road', 'Whitefield'] )
    if st.button("Predict"):
        Results = Make_Prdiction(online_order,book_table,location,approx_cost,listed_in,listed_in_city,rest_type_counts,cuisines_counts)
        list_success = ["Your Resturant May Fail" , "Your Resturant will success"]
        st.text(list_success[Results])
main()
# Out:
# Overwriting app.py

# %%
import joblib
import pickle

# %%
joblib.dump(Final_Model , "Model.pkl",compress=3)
joblib.dump(x.columns , "Inputs.pkl")
# Out:
# ['Inputs.pkl']

# %%
joblib.dump(sampled_df , "data.pkl")
# Out:
# ['data.pkl']

# %%
x.columns
# Out:
# Index(['online_order', 'book_table', 'location', 'rest_type', 'cuisines',
#        'approx_cost(for two people)', 'listed_in(type)', 'listed_in(city)',
#        'Name_repeated'],
#       dtype='object')

# %%
steps = []
steps.append(("Encoder" , Encoder))
steps.append(("Scaler" , RobustScaler()))
steps.append(("Model" , KNeighborsClassifier()) )
pipeline = Pipeline(steps = steps)

# %%
cross_validate(pipeline, x, y, cv=5, scoring=['accuracy'], return_train_score=True)
# Out:
# {'fit_time': array([0.68883848, 0.48723435, 0.95344901, 0.34810185, 0.47461486]),
#  'score_time': array([2.67341161, 2.68174553, 2.8046124 , 2.87746668, 2.84851241]),
#  'test_accuracy': array([0.78602151, 0.84967742, 0.83975048, 0.90083889, 0.84512798]),
#  'train_accuracy': array([0.94101199, 0.93853847, 0.92972363, 0.92423917, 0.9306377 ])}

# %% [markdown]
# # Hyper-parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
steps = []
steps.append(("Encoder" , Encoder))
steps.append(("Scaler" , RobustScaler()))
steps.append(("Model" , KNeighborsClassifier()) )
pipeline = Pipeline(steps = steps)

# %%
# Define the parameter grid for GridSearchCV
params = {
    'Model__n_neighbors': range(4,7),
    'Model__metric': ['minkowski', 'manhattan','hamming'],
    'Model__p': range(1,2)
}

# %%
grid = GridSearchCV(estimator=pipeline , cv = 5 , param_grid=params , scoring="accuracy" , return_train_score=True)

# %%
results = grid.fit(x,y)

# %%
2
# Out:
# 2

# %%
results.cv_results_["mean_train_score"]
# Out:
# array([0.93487344, 0.9345078 , 0.92399032, 0.93487344, 0.9345078 ,
#        0.92399032, 0.95294023, 0.95166049, 0.94176673])

# %%
results.cv_results_["mean_test_score"]
# Out:
# array([0.84419678, 0.85211101, 0.83791613, 0.84419678, 0.85211101,
#        0.83791613, 0.86948894, 0.87447855, 0.86161715])

# %%
results.cv_results_["mean_train_score"]
# Out:
# array([0.94330463, 0.94345519, 0.93280863])

# %%
results.cv_results_["mean_test_score"]
# Out:
# array([0.8576607 , 0.86548887, 0.85236933])

# %%
results.cv_results_["mean_train_score"]
# Out:
# array([0.93283019, 0.92217287, 0.91627968, 0.91025735, 0.90508467])

# %%
results.cv_results_["mean_test_score"]
# Out:
# array([0.84428326, 0.8295292 , 0.8335291 , 0.82144186, 0.8253558 ])

# %%
results.best_params_
# Out:
# {'Model__metric': 'hamming', 'Model__n_neighbors': 5, 'Model__p': 1}

# %%
Final_Model = results.best_estimator_

# %%
Final_Model.fit(x,y)
# Out:
# Pipeline(steps=[('Encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('BE', BinaryEncoder(),
#                                                   ['online_order', 'book_table',
#                                                    'listed_in(type)',
#                                                    'location',
#                                                    'listed_in(city)',
#                                                    'rest_type',
#                                                    'cuisines'])])),
#                 ('Scaler', RobustScaler()),
#                 ('Model', KNeighborsClassifier(metric='hamming', p=1))])

# %%
df[df['rate'] == 0]
# Out:
#       online_order book_table  rate      location           rest_type  \
# 3               No         No     0  Banashankari         Quick Bites
# 20             Yes         No     0  Banashankari                Cafe
# 21             Yes         No     0  Banashankari                Cafe
# 23             Yes         No     0  Banashankari   Quick Bites, Cafe
# 31             Yes         No     0  Banashankari         Quick Bites
# ...            ...        ...   ...           ...                 ...
# 51595           No        Yes     0    Whitefield              Lounge
# 51604           No        Yes     0    Whitefield              Lounge
# 51605           No         No     0    Whitefield  Casual Dining, Bar
# 51636           No         No     0    Whitefield  Casual Dining, Bar
# 51639           No         No     0    Whitefield  Casual Dining, Bar
#
#                                           cuisines  \
# 3                       South Indian, North Indian
# ...

# %%
df['location'].str.contains('Koramangala').sum()
# Out:
# 7778

# %%
df = df.dropna(subset= ['location'])

# %%
df_kor = df[df['location'].str.contains('Koramangala')]
df_kor_list = df_kor['location'].unique()
df['location'] = df['location'].replace(df_kor_list, 'Koramangala')
# Out:
# C:\Users\Seif\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['cuisines'].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ..., 'Andhra, Hyderabadi, Biryani',
#        'Andhra, North Indian, South Indian', 'Thai, Chinese, Momos'],
#       dtype=object)

# %%
len(df['location'].unique())
# Out:
# 85

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'listed_in(city)' column
df['listed_in(city)'] = label_encoder.fit_transform(df['listed_in(city)'])

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51640  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51641                           Vinod Bar And Restaurant           No
# 51642  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51643  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51644                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %%
one_hot_encoder = OneHotEncoder(sparse=False)

# Reshape the 'online_order' column
online_order_reshaped = df['online_order'].values.reshape(-1, 1)

# Fit and transform using OneHotEncoder
encoded_features = one_hot_encoder.fit_transform(online_order_reshaped)

# Create a new DataFrame with the encoded features
encoded_df = pd.DataFrame(encoded_features, columns=one_hot_encoder.get_feature_names_out(['online_order']))

# %%
encoded_df
# Out:
#        online_order_No  online_order_Yes
# 0                  0.0               1.0
# 1                  0.0               1.0
# 2                  0.0               1.0
# 3                  1.0               0.0
# 4                  1.0               0.0
# ...                ...               ...
# 51640              1.0               0.0
# 51641              1.0               0.0
# 51642              1.0               0.0
# 51643              1.0               0.0
# 51644              1.0               0.0
#
# [51645 rows x 2 columns]

# %%
df['name'].nunique()
# Out:
# 8792
